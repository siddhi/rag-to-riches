# %%
import instructor
from openai import OpenAI
from typing import Iterable, Literal, List, Optional, Tuple
from pydantic import BaseModel, Field 
import pandas as pd
from dotenv import find_dotenv, load_dotenv

_ = load_dotenv(find_dotenv())

# %%
client = instructor.from_openai(OpenAI(), mode=instructor.Mode.TOOLS)

class Facet(BaseModel):
    """
    Facet is a search filter e.g. color, size, price, etc.
    """
    name: str = Field(..., description="Common filters in search e.g. color, size, price, gender, brand, fit, cut,datetime, season, pattern, material, dimension, etc.")
    values: List[str] = Field(..., description="Values of the facet")

class QueryAnnotation(BaseModel):
    query: str = Field(..., description="Query to search for relevant content")
    simplified_query: str = Field(..., description="Simplified query e.g. wristwatches for men -> men's wristwatches, red dress shirt for husband -> men's red dress shirt")
    hypothetical_product_description: Optional[List[str]] = Field(..., description="Given a query, generate unique and diverse product descriptions that satisfy the query")
    keywords: List[str] = Field(..., description=   "Keywords to search for")
    expanded_keywords: List[str] = Field(..., description="Expanded keywords to search for e.g. synonyms, related words, etc.")
    intent: Literal["informational", "navigational", "transactional"] = Field(..., description="Intent of the user")
    translated_query: Optional[str] = Field(..., description="English query to search for")
    iso_language_code: Optional[str] = Field(..., description="ISO language code to search e.g. en-US, in-IN")
    facets: List[Facet] = Field(..., description="Facets which are used to filter the search results")

    async def execute(self):
        print(
            f"Decomposing query `{self.query}` into `{self.simplified_query}` and `{self.semantic_query}`"
        )

# %%
df = pd.read_json("amzn_esci_train_query_info.jsonl", lines=True)
df.head()
# Out:
#    qid                                             q_text
# 0    1                       !awnmower tires without rims
# 1    5            # 10 self-seal envelopes without window
# 2    6                          # 2 pencils not sharpened
# 3    9                                         # mom life
# 4   11  #1 best and not expensive bath back brush crea...

# %% [markdown]
# query = f(queries, products, user_actions)

# %%
def query_annotation(data: str) -> Iterable[QueryAnnotation]:
    return client.chat.completions.create(
        model="gpt-4o",
        response_model=Iterable[QueryAnnotation],
        messages=[
            {
                "role": "user",
                "content": f"Consider the user query below: '\n{data}' and annotate the query",
            },
        ],
        max_tokens=1000,
        temperature=0.0,
        seed=42,
    )

def image_query_annotation(url: str, query: str) -> Iterable[QueryAnnotation]:
    return client.chat.completions.create(
        model="gpt-4o",
        response_model=Iterable[QueryAnnotation],
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "image_url",
                        "image_url": {"url": url},
                    },
                    {
                        "type": "text",
                        "text": f"Analyze the image and annotate the query: {query}",
                    },
                ],
            }
        ],
        max_tokens=1000,
        temperature=0.0,
        seed=42,
    )

for query in query_annotation("I'm looking for a red dress shirt for my husband for a Bertem wedding"):
    print(query.model_dump_json(indent=2))
# Out:
# {
#   "query": "I'm looking for a red dress shirt for my husband for a Bertem wedding",
#   "simplified_query": "men's red dress shirt",
#   "hypothetical_product_description": [
#     "A stylish men's red dress shirt perfect for weddings and formal occasions, featuring a slim fit and high-quality fabric.",
#     "Elegant red dress shirt for men, ideal for weddings, with a classic collar and button-down design.",
#     "Men's red dress shirt crafted from breathable material, suitable for weddings and special events, offering comfort and style."
#   ],
#   "keywords": [
#     "red dress shirt",
#     "men's dress shirt",
#     "wedding shirt"
#   ],
#   "expanded_keywords": [
#     "men's red shirt",
#     "formal red shirt",
#     "wedding attire",
#     "husband's dress shirt"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "color",
#       "values": [
#         "red"
#       ]
#     },
#     {
#       "name": "gender",
#       "values": [
#         "men"
#       ]
#     },
#     {
#       "name": "occasion",
#       "values": [
#         "wedding"
#       ]
#     }
#   ]
# }

# %%
from IPython.display import Image
from IPython.core.display import HTML

def display_image_from_url(url: str):
    return Image(url=url)

# Display the image
display(HTML("<h3>Sample Image</h3>"))
display(display_image_from_url("https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Blue_sari_2.jpg/920px-Blue_sari_2.jpg"))


for query in image_query_annotation("https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Blue_sari_2.jpg/920px-Blue_sari_2.jpg", "I'm looking for a kanchipuram silk saree"):
    print(query.model_dump_json(indent=2))
# Out:
# <h3>Sample Image</h3>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Blue_sari_2.jpg/920px-Blue_sari_2.jpg"/>
# {
#   "query": "kanchipuram silk saree",
#   "simplified_query": "kanchipuram silk saree",
#   "hypothetical_product_description": [
#     "A luxurious Kanchipuram silk saree with intricate zari work, perfect for weddings and special occasions.",
#     "Elegant Kanchipuram silk saree featuring traditional motifs and a rich pallu, ideal for festive celebrations.",
#     "Classic Kanchipuram silk saree in vibrant colors with a contrasting border, suitable for formal events."
#   ],
#   "keywords": [
#     "kanchipuram",
#     "silk",
#     "saree"
#   ],
#   "expanded_keywords": [
#     "kanchipuram saree",
#     "silk saree",
#     "kanchipuram silk",
#     "traditional saree",
#     "wedding saree"
#   ],
#   "intent": "transactional",
#   "translated_query": "kanchipuram silk saree",
#   "iso_language_code": "en-US",
#   "facets": [
#     {
#       "name": "material",
#       "values": [
#         "silk"
#       ]
#     },
#     {
#       "name": "type",
#       "values": [
#         "kanchipuram"
#       ]
#     }
#   ]
# }

# %%
# Pull 100 random queries from the df and display
def display_annotated_queries(queries: List[str]):
    for query in queries:
        annotated_queries = query_annotation(query)
        for annotated_query in annotated_queries:
            print(f"Query: {query}")
            print(f"Annotated Query: {annotated_query.model_dump_json(indent=2)}")
            print("\n")

seed = 69
queries = df["q_text"].sample(10, random_state=seed).tolist()
display_annotated_queries(queries)
# Out:
# Query: waterproof kid gloves small
# Annotated Query: {
#   "query": "waterproof kid gloves small",
#   "simplified_query": "small waterproof gloves for kids",
#   "hypothetical_product_description": [
#     "These small waterproof gloves for kids are perfect for rainy days and outdoor adventures. Made with durable, water-resistant material, they keep little hands dry and comfortable.",
#     "Designed for children, these small waterproof gloves offer excellent protection against the elements. Ideal for playing in the snow or rain, they ensure warmth and dryness.",
#     "Keep your child's hands warm and dry with these small waterproof gloves. Perfect for winter sports or rainy weather, they are both functional and stylish."
#   ],
#   "keywords": [
#     "waterproof",
#     "kid gloves",
#     "small"
#   ],
#   "expanded_keywords": [
#     "children's waterproof gloves",
#     "small size gloves for kids",
#     "water-resistant gloves for children"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "size",
#       "values": [
#         "small"
#       ]
#     },
#     {
#       "name": "age group",
#       "values": [
#         "kids"
#       ]
#     },
#     {
#       "name": "feature",
#       "values": [
#         "waterproof"
#       ]
#     }
#   ]
# }
#
#
# Query: black marble blanket
# Annotated Query: {
#   "query": "black marble blanket",
#   "simplified_query": "black marble blanket",
#   "hypothetical_product_description": [
#     "A luxurious black marble-patterned blanket made from soft, high-quality fleece, perfect for adding a touch of elegance to your living room or bedroom.",
#     "A cozy and warm black marble blanket crafted from premium cotton, ideal for snuggling up on chilly nights.",
#     "An elegant black marble design blanket with a silky texture, suitable for both modern and classic home decor styles."
#   ],
#   "keywords": [
#     "black marble blanket",
#     "marble pattern blanket",
#     "black blanket"
#   ],
#   "expanded_keywords": [
#     "black marble throw",
#     "marble design blanket",
#     "black and white blanket",
#     "luxury blanket",
#     "decorative blanket"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "color",
#       "values": [
#         "black"
#       ]
#     },
#     {
#       "name": "pattern",
#       "values": [
#         "marble"
#       ]
#     },
#     {
#       "name": "material",
#       "values": [
#         "fleece",
#         "cotton",
#         "silk"
#       ]
#     }
#   ]
# }
#
#
# Query: purple race car toy
# Annotated Query: {
#   "query": "purple race car toy",
#   "simplified_query": "purple race car toy",
#   "hypothetical_product_description": [
#     "A sleek and vibrant purple race car toy designed for children aged 3 and up, featuring realistic racing sounds and lights.",
#     "A durable and lightweight purple race car toy with pull-back action, perfect for indoor and outdoor play.",
#     "A collectible purple race car toy with intricate detailing and a glossy finish, ideal for car enthusiasts of all ages."
#   ],
#   "keywords": [
#     "purple",
#     "race car",
#     "toy"
#   ],
#   "expanded_keywords": [
#     "violet",
#     "racing car",
#     "children's toy",
#     "play car",
#     "model car"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "color",
#       "values": [
#         "purple"
#       ]
#     },
#     {
#       "name": "type",
#       "values": [
#         "race car"
#       ]
#     },
#     {
#       "name": "category",
#       "values": [
#         "toy"
#       ]
#     }
#   ]
# }
#
#
# Query: necklace with name
# Annotated Query: {
#   "query": "necklace with name",
#   "simplified_query": "personalized name necklace",
#   "hypothetical_product_description": [
#     "A beautiful gold necklace featuring a customizable name pendant, perfect for personalizing your jewelry collection.",
#     "A sterling silver necklace with a nameplate that can be engraved with any name of your choice, ideal for gifting.",
#     "A trendy rose gold necklace with a delicate chain and a customizable name charm, suitable for everyday wear."
#   ],
#   "keywords": [
#     "necklace",
#     "name",
#     "personalized",
#     "custom",
#     "engraved"
#   ],
#   "expanded_keywords": [
#     "name necklace",
#     "custom necklace",
#     "engraved necklace",
#     "personalized jewelry",
#     "nameplate necklace"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "material",
#       "values": [
#         "gold",
#         "silver",
#         "rose gold"
#       ]
#     },
#     {
#       "name": "style",
#       "values": [
#         "nameplate",
#         "engraved",
#         "custom"
#       ]
#     },
#     {
#       "name": "occasion",
#       "values": [
#         "gift",
#         "everyday wear"
#       ]
#     }
#   ]
# }
#
#
# Query: dogs
# Annotated Query: {
#   "query": "dogs",
#   "simplified_query": "dogs",
#   "hypothetical_product_description": [
#     "A comprehensive guide to dog breeds, including their characteristics, care needs, and training tips.",
#     "A collection of high-quality dog food tailored to different breeds and dietary needs.",
#     "A range of stylish and comfortable dog accessories, including collars, leashes, and harnesses.",
#     "An assortment of dog toys designed to keep your pet entertained and mentally stimulated.",
#     "A selection of dog grooming products to keep your pet looking and feeling their best."
#   ],
#   "keywords": [
#     "dogs"
#   ],
#   "expanded_keywords": [
#     "canines",
#     "puppies",
#     "dog breeds",
#     "pet dogs",
#     "domestic dogs"
#   ],
#   "intent": "informational",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "type",
#       "values": [
#         "breeds",
#         "food",
#         "accessories",
#         "toys",
#         "grooming"
#       ]
#     },
#     {
#       "name": "purpose",
#       "values": [
#         "care",
#         "training",
#         "entertainment",
#         "nutrition",
#         "grooming"
#       ]
#     }
#   ]
# }
#
#
# Query: adhesive document pockets 9.5 x 12
# Annotated Query: {
#   "query": "adhesive document pockets 9.5 x 12",
#   "simplified_query": "adhesive document pockets 9.5 x 12",
#   "hypothetical_product_description": [
#     "A pack of adhesive document pockets measuring 9.5 x 12 inches, perfect for organizing and protecting important documents. These pockets are made from durable, transparent material and feature a strong adhesive backing for easy attachment to various surfaces.",
#     "High-quality adhesive document pockets sized at 9.5 x 12 inches, ideal for office and home use. These pockets are designed to hold and display documents securely, with a peel-and-stick adhesive that ensures they stay in place.",
#     "Set of adhesive document pockets, each 9.5 x 12 inches, crafted from clear, tear-resistant plastic. These pockets are perfect for storing documents, photos, or certificates, and can be easily attached to walls, doors, or bulletin boards."
#   ],
#   "keywords": [
#     "adhesive document pockets",
#     "9.5 x 12"
#   ],
#   "expanded_keywords": [
#     "self-adhesive document holders",
#     "9.5 x 12 inch document sleeves",
#     "sticky document pockets",
#     "adhesive file pockets",
#     "9.5 x 12 adhesive sleeves"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "size",
#       "values": [
#         "9.5 x 12"
#       ]
#     },
#     {
#       "name": "material",
#       "values": [
#         "plastic",
#         "transparent"
#       ]
#     },
#     {
#       "name": "feature",
#       "values": [
#         "adhesive",
#         "self-adhesive"
#       ]
#     }
#   ]
# }
#
#
# Query: soccer clothes for girls
# Annotated Query: {
#   "query": "soccer clothes for girls",
#   "simplified_query": "girls' soccer clothes",
#   "hypothetical_product_description": [
#     "A stylish and comfortable soccer jersey and shorts set for girls, made from breathable material to keep young athletes cool during play.",
#     "Durable and lightweight soccer cleats designed specifically for girls, offering excellent grip and support on the field.",
#     "A girls' soccer training kit that includes a moisture-wicking top, shorts, and socks, perfect for practice sessions.",
#     "Colorful and protective shin guards for girls, ensuring safety and comfort during soccer matches.",
#     "A girls' soccer hoodie and sweatpants set, ideal for warming up or casual wear, featuring a trendy design."
#   ],
#   "keywords": [
#     "soccer",
#     "clothes",
#     "girls"
#   ],
#   "expanded_keywords": [
#     "soccer apparel",
#     "girls' sportswear",
#     "youth soccer clothing",
#     "girls' athletic wear",
#     "soccer gear for girls"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "gender",
#       "values": [
#         "girls"
#       ]
#     },
#     {
#       "name": "sport",
#       "values": [
#         "soccer"
#       ]
#     }
#   ]
# }
#
#
# Query: how to not give a fck book
# Annotated Query: {
#   "query": "how to not give a fck book",
#   "simplified_query": "how to not give a f*ck book",
#   "hypothetical_product_description": [
#     "A self-help book that teaches readers how to stop caring about things that don't matter and focus on what truly makes them happy.",
#     "A guide to living a stress-free life by letting go of unnecessary worries and societal pressures.",
#     "A humorous and practical approach to personal development, encouraging readers to prioritize their own happiness."
#   ],
#   "keywords": [
#     "how to not give a f*ck",
#     "book",
#     "self-help",
#     "care less",
#     "stress-free"
#   ],
#   "expanded_keywords": [
#     "how to not give a f*ck",
#     "self-help book",
#     "care less",
#     "stress-free living",
#     "personal development"
#   ],
#   "intent": "informational",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "genre",
#       "values": [
#         "self-help",
#         "personal development"
#       ]
#     },
#     {
#       "name": "tone",
#       "values": [
#         "humorous",
#         "practical"
#       ]
#     }
#   ]
# }
#
#
# Query: call of duty modern warfare xbox one
# Annotated Query: {
#   "query": "call of duty modern warfare xbox one",
#   "simplified_query": "call of duty modern warfare xbox one",
#   "hypothetical_product_description": [
#     "Call of Duty: Modern Warfare for Xbox One - Experience the intense action and thrilling gameplay of this popular first-person shooter game. Join the fight in a gripping single-player campaign or engage in competitive multiplayer modes. Compatible with Xbox One consoles.",
#     "Call of Duty: Modern Warfare Xbox One Edition - Dive into the critically acclaimed game with stunning graphics and immersive sound. Perfect for fans of action-packed military games. Available for Xbox One.",
#     "Call of Duty: Modern Warfare Game for Xbox One - Get ready for an adrenaline-pumping experience with this top-rated shooter game. Features realistic graphics and engaging storylines. Designed for Xbox One players."
#   ],
#   "keywords": [
#     "call of duty",
#     "modern warfare",
#     "xbox one"
#   ],
#   "expanded_keywords": [
#     "call of duty game",
#     "modern warfare xbox",
#     "xbox one games",
#     "call of duty xbox one",
#     "modern warfare game"
#   ],
#   "intent": "transactional",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "platform",
#       "values": [
#         "Xbox One"
#       ]
#     },
#     {
#       "name": "game series",
#       "values": [
#         "Call of Duty"
#       ]
#     },
#     {
#       "name": "edition",
#       "values": [
#         "Modern Warfare"
#       ]
#     }
#   ]
# }
#
#
# Query: fingerpow
# Annotated Query: {
#   "query": "fingerpow",
#   "simplified_query": "fingerpow",
#   "hypothetical_product_description": [
#     "Fingerpow is a compact and portable power bank that allows you to charge your devices on the go. It features a magnetic connection for easy attachment and detachment, making it convenient for travel and daily use.",
#     "Fingerpow offers a unique charging solution with its modular design, allowing users to carry multiple small power pods that can be used individually or together for extended power supply.",
#     "The Fingerpow power bank is designed for efficiency and style, providing fast charging capabilities in a sleek and lightweight form factor, perfect for tech-savvy individuals."
#   ],
#   "keywords": [
#     "fingerpow",
#     "power bank",
#     "portable charger"
#   ],
#   "expanded_keywords": [
#     "fingerpow charger",
#     "magnetic power bank",
#     "modular power bank",
#     "portable charging solution"
#   ],
#   "intent": "informational",
#   "translated_query": null,
#   "iso_language_code": null,
#   "facets": [
#     {
#       "name": "type",
#       "values": [
#         "power bank",
#         "charger"
#       ]
#     },
#     {
#       "name": "feature",
#       "values": [
#         "magnetic",
#         "modular",
#         "portable"
#       ]
#     }
#   ]
# }
